# %%
import pandas as pd
import matplotlib.pyplot as plt
import pathlib
import numpy as np

#設定
#agent_type = "TimeChange_Communication"
agent_type = "CommunicatiNG"
target_type = "5-AMTDS-ESC"
date = "05-31 18-42-27 robots-number=20_1"
agent_N = 20

for i in range(agent_N):
    df = pd.read_csv("../../../../Volumes/ExternalDisk1/Patrolling/log/TTest/" +  agent_type + "/Office/5-AMTDS-ESC/" + date  + "/Agent" + str(i) + "/SearchNode.csv", names=['time','num', 'x', 'y'] , header=None)

    #プロット
    plt.plot(df['time'], df['num'], color="red", label="AMTDS/ERC")

    #ラベルの追加
    plt.xlabel('Time(steps)')
    plt.ylabel('Number of Responsible Nodes $N^i_R$')

    #表示範囲の指定
    plt.xlim(0, 4000000)
    #plt.ylim(1200000, 1800000)
    
    plt.xticks([0, 1000000, 2000000, 3000000, 4000000])

    #凡例の追加
    plt.legend()

    #指数表記から普通の表記に変換
    plt.ticklabel_format(style='plain',axis='x')
    plt.ticklabel_format(style='plain',axis='y')

    #フォルダがない場合は，作成
    p_dir = pathlib.Path("../../../../Volumes/ExternalDisk1/Patrolling/result/searchNum")
    if not p_dir.exists():
        p_dir.mkdir(parents=True)
    
    #グラフの保存
    plt.savefig(str(p_dir) + '/' + 'searchNum_' + date + '_Agent' + str(i) + '.png'
                , bbox_inches='tight')

    #グラフの表示
    plt.show()

print("Showing graph is completed.")
# Out:
# Showing graph is completed.
