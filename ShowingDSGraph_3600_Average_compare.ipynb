# %%
#evaluation-s3600(間隔3600ステップでのD(s)計算)のcsvファイルからD(s)の時間変化の平均値のグラフを出力するプログラム
import pandas as pd
import matplotlib.pyplot as plt
import pathlib
import datetime
import matplotlib.cm as cm
import os

#どれを表示するか
AMTDS_flag = True
LD_flag = False
EDC_flag = False
THE_flag = False

Base_flag = False

TimeChange_flag = True

ERC_flag = False

Onebyone_flag = True

Multiple_flag = False

Request_flag = True

#AMTDS
if AMTDS_flag == True:
    #設定
    file_count = 50
    agent_type = "normal"
    #date = "04-24 05-16-57 robots-number=20"
    #date = "04-10 02-38-05 robots-number=20"
    #date = "06-30 19-58-39 robots-number=20"
    date = "07-06 05-48-13 robots-number=20"
    #date = "07-03 01-57-53 robots-number=20"
    env = "Office"
    env = "Complex"
    
    for i in range(1, file_count + 1):
        df = pd.read_csv("../../../../Volumes/ExternalDisk1/Patrolling/log/TTest/" +  agent_type + "/" + env + "/5-AMTDS-ESC/" + date  + "_" + str(i) + "/evaluation-s3600.csv", names=['time','ds', 'maxLitterAmount', 'cs'] , header=None)
        if(i == 1):
            df_sum = df
        else:
            df_sum += df

    #平均値計算
    ave_df = df_sum / file_count
    mean_df = ave_df['ds'].mean()
    print(mean_df)

    #プロット
    plt.plot(ave_df['time'], ave_df['ds'], color="blue", label="AMTDS")
    
#AMTDS/LD
if LD_flag == True:
    #設定
    file_count = 50
    agent_type = "PDALearning"
    #date = "04-14 15-29-10 robots-number=20"
    #date = "05-09 02-45-37 robots-number=20"
    date = "05-18 18-59-51 robots-number=20"
    env = "Office"
    
    for i in range(1, file_count + 1):
        df = pd.read_csv("../../../../Volumes/ExternalDisk1/Patrolling/log/TTest/" +  agent_type + "/" + env + "/5-AMTDS-ESC/" + date  + "_" + str(i) + "/evaluation-s3600.csv", names=['time','ds', 'maxLitterAmount', 'cs'] , header=None)
        if(i == 1):
            df_sum = df
        else:
            df_sum += df

    #平均値計算
    ave_df = df_sum / file_count
    mean_df = ave_df['ds'].mean()
    print(mean_df)

    #プロット
    plt.plot(ave_df['time'], ave_df['ds'], color="blue", label="AMTDS/LD")

#AMTDS/EDC
if EDC_flag == True:
    #設定
    file_count = 50
    agent_type = "Communicating"
    #date = "05-31 19-11-20 robots-number=20"
    #date = "05-31 18-42-27 robots-number=20"
    date = "06-22 17-52-28 robots-number=20"

    for i in range(1, file_count + 1):
        df = pd.read_csv("../../../../Volumes/ExternalDisk1/Patrolling/log/TTest/" +  agent_type + "/Office/5-AMTDS-ESC/" + date  + "_" + str(i) + "/evaluation-s3600.csv", names=['time','ds', 'maxLitterAmount', 'cs'] , header=None)
        if(i == 1):
            df_sum = df
        else:
            df_sum += df

    #平均値計算
    ave_df = df_sum / file_count

    #プロット
    plt.plot(ave_df['time'], ave_df['ds'], color="blue", label="AMTDS/EDC")

#AMTDS/THE
if THE_flag == True:
    #設定
    file_count = 10
    count = 3
    agent_type = "PlannedStopping"
    #date = ["02-03 02-14-07", "02-04 14-03-46", "02-13 23-46-41", "02-14 14-08-31"]
    #time = ["500,000", "50,000", "5,000", "500"]
    
    date = ["02-03 02-14-07", "02-04 14-03-46", "02-13 23-46-41"]
    time = ["500,000", "50,000", "5,000"]

    for j in range(count):
        for i in range(1, file_count + 1):
            df = pd.read_csv("./log/PTest/" +  agent_type + "/Office/4-AMTDS-LD/" + date[j] + " robots-number=20"  + "_" + str(i) + "/evaluation-s3600.csv", names=['time','ds', 'maxLitterAmount'] , header=None)
            if(i == 1):
                df_sum = df
            else:
                df_sum += df

        #平均値計算
        ave_df = df_sum / file_count

        #プロット
        plt.plot(ave_df['time'], ave_df['ds'], color=cm.hsv(j/float(count)), label="THE: " + time[j])

#Baseline
if Base_flag == True:
    #設定
    file_count = 50
    agent_type = "TimeChange"
    #agent_type = "TimeChange_Learning"
    #date = "06-09 04-43-05 robots-number=20"
    #date = "06-11 04-32-34 robots-number=20"
    #date = "06-13 01-05-09 robots-number=20"
    #date = "06-14 23-36-28 robots-number=20"
    date = "10-07 00-31-08 robots-number=20"
    env = "Office"
    
    for i in range(1, file_count + 1):
        df = pd.read_csv("../../../../Volumes/ExternalDisk1/Patrolling/log/TTest/" +  agent_type + "/" + env + "/5-AMTDS-ESC/" + date  + "_" + str(i) + "/evaluation-s3600.csv", names=['time','ds', 'maxLitterAmount', 'cs'] , header=None)
        if(i == 1):
            df_sum = df
        else:
            df_sum += df
    
    #平均値計算
    ave_df = df_sum / file_count
    mean_df = ave_df['ds'].mean()
    print(mean_df)

    #プロット
    plt.plot(ave_df['time'], ave_df['ds'], color="red", label="Homing&Pausing")
        
#TimeChange
if TimeChange_flag == True:
    #設定
    file_count = 25
    agent_type = "TimeChange"
    #date = "08-07 00-19-47 robots-number=20"
    date = "10-17 07-20-19 robots-number=20"
    #date = "09-19 22-18-22 robots-number=20"
    
    env = "Office"
    
    for i in range(1, file_count + 1):
        df = pd.read_csv("../../../../Volumes/ExternalDisk1/Patrolling/log/TTest/" +  agent_type + "/" + env + "/5-AMTDS-ESC/" + date  + "_" + str(i) + "/evaluation-s3600.csv", names=['time','ds', 'maxLitterAmount', 'cs'] , header=None)
        if(i == 1):
            df_sum = df
        else:
            df_sum += df

      #平均値計算
    ave_df = df_sum / file_count
    mean_df = ave_df['ds'].mean()
    print(mean_df)

    #プロット
    plt.plot(ave_df['time'], ave_df['ds'], color="black", label="AMTDS/ER")
    
#ERC
if ERC_flag == True:
    #設定
    file_count = 50
    agent_type = "TimeChange_Communication"
    #date = "06-05 18-24-24 robots-number=20"
    #date = "06-15 00-39-42 robots-number=20"
    date = "06-18 05-57-06 robots-number=20"
    env = "Office"
    
    for i in range(1, file_count + 1):
        df = pd.read_csv("../../../../Volumes/ExternalDisk1/Patrolling/log/TTest/" +  agent_type + "/" + env + "/5-AMTDS-ESC/" + date  + "_" + str(i) + "/evaluation-s3600.csv", names=['time','ds', 'maxLitterAmount', 'cs'] , header=None)
        if(i == 1):
            df_sum = df
        else:
            df_sum += df
    
    #平均値計算
    ave_df = df_sum / file_count
    mean_df = ave_df['ds'].mean()
    print(mean_df)

    #プロット
    plt.plot(ave_df['time'], ave_df['ds'], color="red", label="AMTDS/ERC")

#Onebyone
if Onebyone_flag == True:
    #設定
    file_count = 50
    agent_type = "Onebyone"
    date = "10-12 00-21-38 robots-number=20"
    date = "10-14 05-09-27 robots-number=20"
    env = "Complex"
    
    for i in range(1, file_count + 1):
        df = pd.read_csv("../../../../Volumes/ExternalDisk1/Patrolling/log/OTest/" +  agent_type + "/" + env + "/5-AMTDS-ESC/" + date  + "_" + str(i) + "/evaluation-s3600.csv", names=['time','ds', 'maxLitterAmount', 'cs'] , header=None)
        if(i == 1):
            df_sum = df
        else:
            df_sum += df
    
    #平均値計算
    sTime = 4000000
    eTime = 5000000
    ave_df = df_sum / file_count
    mean_df = ave_df[(ave_df["time"] > sTime) & (ave_df["time"] <= eTime)]['ds'].mean()
    print(mean_df)

    #プロット
    plt.plot(ave_df['time'], ave_df['ds'], color="red", label="With deactivation")

#Multiple
if Multiple_flag == True:
    #設定
    file_count = 50
    agent_type = "Onebyone"
    date = "09-17 23-47-20 robots-number=20"
    env = "Office"
    
    for i in range(1, file_count + 1):
        df = pd.read_csv("../../../../Volumes/ExternalDisk1/Patrolling/log/MTest/" +  agent_type + "/" + env + "/5-AMTDS-ESC/" + date  + "_" + str(i) + "/evaluation-s3600.csv", names=['time','ds', 'maxLitterAmount', 'cs'] , header=None)
        if(i == 1):
            df_sum = df
        else:
            df_sum += df
    
    #平均値計算
    ave_df = df_sum / file_count
    mean_df = ave_df['ds'].mean()
    print(mean_df)

    #プロット
    plt.plot(ave_df['time'], ave_df['ds'], color="gold", label="Multiple")    
    
if Request_flag == True:
    request = 600.0
    df_req = pd.DataFrame([[0.0, request*3600, 0.0, 0.0], [5000000.0, request*3600, 0.0, 0.0]], columns=['time', 'ds', 'maxLitteerAmount', 'energy'])
    plt.plot(df_req['time'], df_req['ds'], color="green", label="Reqirement")
    
    #request2 = 600.0
    #request1 = 1000.0
    #df_req = pd.DataFrame([[0.0, request1*3600, 0.0, 0.0], [2000000.0, request1*3600, 0.0, 0.0]], columns=['time', 'ds', 'maxLitteerAmount', 'energy'])
    #plt.plot(df_req['time'], df_req['ds'], color="green", label="Reqirement")
    
    #df_req = pd.DataFrame([[2000000.0, request2*3600, 0.0, 0.0], [3500000.0, request2*3600, 0.0, 0.0]], columns=['time', 'ds', 'maxLitteerAmount', 'energy'])
    #plt.plot(df_req['time'], df_req['ds'], color="green")
    
    #request = 1000.0
    #df_req = pd.DataFrame([[3500000.0, request1*3600, 0.0, 0.0], [5000000.0, request1*3600, 0.0, 0.0]], columns=['time', 'ds', 'maxLitteerAmount', 'energy'])
    #plt.plot(df_req['time'], df_req['ds'], color="green")
    
    #plt.vlines(2000000.0, request1*3600, request2*3600, color="green", linestyles="dotted")
    #plt.vlines(3500000.0, request1*3600, request2*3600, color="green", linestyles="dotted")
    
    
#ラベルの追加
plt.xlabel('Time(steps)')
plt.ylabel('Cumulative existance duration of events D(s)')

#表示範囲の指定
plt.xlim(0, 5000000)
#plt.xlim(3000000, 4000000)
#plt.xlim(1500000, 2500000)
plt.ylim(0, 2500000)
#plt.ylim(0, 4000000)
#plt.ylim(3000000, 4000000)

plt.xticks([0, 1000000, 2000000, 3000000, 4000000, 5000000])

#凡例の追加
plt.legend()

#指数表記から普通の表記に変換
plt.ticklabel_format(style='plain',axis='x')
plt.ticklabel_format(style='plain',axis='y')

#フォルダがない場合は、作成
p_dir = pathlib.Path("../../../../Volumes/ExternalDisk1/Patrolling/result/ds_graph_ave_compare")
if not p_dir.exists():
    p_dir.mkdir(parents=True)
    
#日付
date = datetime.datetime.now().strftime('%Y-%m-%d %H-%M-%S')

#グラフの保存
plt.savefig(str(p_dir) + '/' + 'ds_graph_3600_ave_compare' + date +'.png'
           , bbox_inches="tight")

#グラフの表示
plt.show()

print("Showing D(s) Average Comparing graph is completed.")
# Out:
# 883730.4437643682
# 2330650.2325521195
# 2104897.33768953
# Showing D(s) Average Comparing graph is completed.
