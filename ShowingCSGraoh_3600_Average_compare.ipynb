# %%
#evaluation-s3600(間隔3600ステップでのC(s)計算)のcsvファイルからC(s)の時間変化の平均値のグラフを出力するプログラム
import pandas as pd
import matplotlib.pyplot as plt
import pathlib
import datetime
import matplotlib.cm as cm

#どれを表示するか
AMTDS_flag = True
LD_flag = False
EDC_flag = False
THE_flag = False

TimeChange_flag = True

CycleLearning_flag = False

ERC_flag = False

Base_flag = False

Onebyone_flag = True

Multiple_flag = False

#AMTDS
if AMTDS_flag == True:
    #設定
    file_count = 50
    agent_type = "normal"
    target_type = "5-AMTDS-ESC"
    #date = "08-01 21-01-04 robots-number=20"
    date = "07-06 05-48-13 robots-number=20"
    #date = "07-03 01-57-53 robots-number=20"
    env = "Complex"
    
    
    for i in range(1, file_count + 1):
        df = pd.read_csv("../../../../Volumes/ExternalDisk1/Patrolling/log/TTest/" +  agent_type + "/" + env + "/" + target_type + "/" + date  + "_" + str(i) + "/evaluation-s3600.csv", names=['time','ds', 'maxLitterAmount', 'cs'] , header=None)
        if(i == 1):
            df_sum = df
        else:
            df_sum += df

    #平均値計算
    ave_df = df_sum / file_count
    mean_df = ave_df['cs'].mean()
    print(mean_df)

    #プロット
    plt.plot(ave_df['time'], ave_df['cs'], color="blue", label="AMTDS")
    
#AMTDS/LD
if LD_flag == True:
    #設定
    file_count = 50
    agent_type = "PDALearning"
    #date = "04-14 15-29-10 robots-number=20"
    #date = "05-09 02-45-37 robots-number=20"
    date = "05-18 18-59-51 robots-number=20"
    env = "Office"

    for i in range(1, file_count + 1):
        df = pd.read_csv("../../../../Volumes/ExternalDisk1/Patrolling/log/TTest/" +  agent_type + "/" + env + "/5-AMTDS-ESC/" + date  + "_" + str(i) + "/evaluation-s3600.csv", names=['time','ds', 'maxLitterAmount', 'cs'] , header=None)
        if(i == 1):
            df_sum = df
        else:
            df_sum += df

    #平均値計算
    ave_df = df_sum / file_count
    mean_df = ave_df['cs'].mean()
    print("AMTDS/LD : ")
    print(mean_df)

    #プロット
    plt.plot(ave_df['time'], ave_df['cs'], color="blue", label="AMTDS/LD")

#AMTDS/EDC
if EDC_flag == True:
    #設定
    file_count = 50
    agent_type = "Communicating"
    #date = "05-31 18-42-27 robots-number=20"
    date = "06-22 17-52-28 robots-number=20"

    for i in range(1, file_count + 1):
        df = pd.read_csv("../../../../Volumes/ExternalDisk1/Patrolling/log/TTest/" +  agent_type + "/Office/5-AMTDS-ESC/" + date  + "_" + str(i) + "/evaluation-s3600.csv", names=['time','ds', 'maxLitterAmount', 'cs'] , header=None)
        if(i == 1):
            df_sum = df
        else:
            df_sum += df

    #平均値計算
    ave_df = df_sum / file_count

    #プロット
    plt.plot(ave_df['time'], ave_df['cs'], color="blue", label="AMTDS/EDC")


#AMTDS/THE
if THE_flag == True:
    #設定
    file_count = 10
    count = 3
    agent_type = "PlannedStopping"
    #date = ["02-03 02-14-07", "02-04 14-03-46", "02-13 23-46-41", "02-14 14-08-31"]
    #time = ["500,000", "50,000", "5,000", "500"]
    
    date = ["02-03 02-14-07", "02-04 14-03-46", "02-13 23-46-41"]
    time = ["500,000", "50,000", "5,000"]

    for j in range(count):
        for i in range(1, file_count + 1):
            df = pd.read_csv("./log/PTest/" +  agent_type + "/Office/4-AMTDS-LD/" + date[j] + " robots-number=20"  + "_" + str(i) + "/evaluation-s3600.csv", names=['time','ds', 'maxLitterAmount'] , header=None)
            if(i == 1):
                df_sum = df
            else:
                df_sum += df

        #平均値計算
        ave_df = df_sum / file_count

        #プロット
        plt.plot(ave_df['time'], ave_df['cs'], color=cm.hsv(j/float(count)), label="THE: " + time[j])   

#Baseline
if Base_flag == True:
    #設定
    file_count = 50
    target_type = "5-AMTDS-ESC"
    #agent_type = "TimeChange_Learning"
    agent_type = "TimeChange"
    #date = "06-09 04-43-05 robots-number=20"
    #date = "06-11 04-32-34 robots-number=20"
    #date = "06-13 01-05-09 robots-number=20"
    #date = "06-14 23-36-28 robots-number=20"
    date = "06-08 17-34-00 robots-number=20"
    env = "Office"
    
    for i in range(1, file_count + 1):
        df = pd.read_csv("../../../../Volumes/ExternalDisk1/Patrolling/log/TTest/" + agent_type + "/" + env + "/" + target_type + "/" + date  + "_" + str(i) + "/evaluation-s3600.csv", names=['time','ds', 'maxLitterAmount', 'cs'] , header=None)
        if(i == 1):
            df_sum = df
        else:
            df_sum += df

    #平均値計算
    ave_df = df_sum / file_count
    
    mean_df = ave_df['cs'].mean()
    print("K=1 : ")
    print(mean_df)

    #プロット
    plt.plot(ave_df['time'], ave_df['cs'], color="red", label="Homing&Pausing")
      

#TimeChange
if TimeChange_flag == True:
    #設定
    file_count = 50
    target_type = "5-AMTDS-ESC"
    agent_type = "TimeChange"
    #agent_type = "TimeChange_Learning"
    #date = "07-03 20-52-05 robots-number=20"
    date = "09-27 14-26-07 robots-number=20"
    #date = "09-19 22-18-22 robots-number=20"
    env = "Complex"
    
    for i in range(1, file_count + 1):
        df = pd.read_csv("../../../../Volumes/ExternalDisk1/Patrolling/log/TTest/" + agent_type + "/" + env + "/" + target_type + "/" + date  + "_" + str(i) + "/evaluation-s3600.csv", names=['time','ds', 'maxLitterAmount', 'cs'] , header=None)
        if(i == 1):
            df_sum = df
        else:
            df_sum += df

    #平均値計算
    ave_df = df_sum / file_count
    
    mean_df = ave_df['cs'].mean()
    print("TimeChange : ")
    print(mean_df)

    #プロット
    plt.plot(ave_df['time'], ave_df['cs'], color="black", label="AMTDS/ER")
    
#ERC
if ERC_flag == True:
    #設定
    file_count = 50
    target_type = "5-AMTDS-ESC"
    agent_type = "TimeChange_Communication"
    #date = "06-05 18-24-24 robots-number=20"
    #date = "06-15 00-39-42 robots-number=20"
    date = "06-18 05-57-06 robots-number=20"
    
    env = "Office"
    
    for i in range(1, file_count + 1):
        df = pd.read_csv("../../../../Volumes/ExternalDisk1/Patrolling/log/TTest/" + agent_type + "/" + env + "/" + target_type + "/" + date  + "_" + str(i) + "/evaluation-s3600.csv", names=['time','ds', 'maxLitterAmount', 'cs'] , header=None)
        if(i == 1):
            df_sum = df
        else:
            df_sum += df

    #平均値計算
    ave_df = df_sum / file_count
    
    mean_df = ave_df['cs'].mean()
    print("ERC : ")
    print(mean_df)

    #プロット
    plt.plot(ave_df['time'], ave_df['cs'], color="red", label="AMTDS/ERC")

#CycleLearning
if CycleLearning_flag == True:
    #設定
    file_count = 10
    target_type = "5-AMTDS-ESC"
    agent_type = "TimeChange_U"
    date = "08-13 06-31-58 robots-number=20"
    env = "Office"
    
    for i in range(1, file_count + 1):
        df = pd.read_csv("../../../../Volumes/ExternalDisk1/Patrolling/log/UTest/" + agent_type + "/" + env + "/" + target_type + "/" + date  + "_" + str(i) + "/evaluation-s3600.csv", names=['time','ds', 'maxLitterAmount', 'cs'] , header=None)
        if(i == 1):
            df_sum = df
        else:
            df_sum += df

    #平均値計算
    ave_df = df_sum / file_count
    
    mean_df = ave_df['cs'].mean()
    print("CycleLearning : ")
    print(mean_df)

    #プロット
    plt.plot(ave_df['time'], ave_df['cs'], color="red", label="Proposed")
    
#Onebyone
if Onebyone_flag == True:
    #設定
    file_count = 50
    agent_type = "Onebyone"
    date = "10-14 05-09-27 robots-number=20"
    env = "Complex"
    
    for i in range(1, file_count + 1):
        df = pd.read_csv("../../../../Volumes/ExternalDisk1/Patrolling/log/OTest/" +  agent_type + "/" + env + "/5-AMTDS-ESC/" + date  + "_" + str(i) + "/evaluation-s3600.csv", names=['time','ds', 'maxLitterAmount', 'cs'] , header=None)
        if(i == 1):
            df_sum = df
        else:
            df_sum += df
    
    #平均値計算
    ave_df = df_sum / file_count
    mean_df = ave_df['cs'].mean()
    print(mean_df)

    #プロット
    plt.plot(ave_df['time'], ave_df['cs'], color="red", label="With deactiovation")

#Multiple
if Multiple_flag == True:
    #設定
    file_count = 50
    agent_type = "Onebyone"
    date = "09-17 23-47-20 robots-number=20"
    env = "Office"
    
    for i in range(1, file_count + 1):
        df = pd.read_csv("../../../../Volumes/ExternalDisk1/Patrolling/log/MTest/" +  agent_type + "/" + env + "/5-AMTDS-ESC/" + date  + "_" + str(i) + "/evaluation-s3600.csv", names=['time','ds', 'maxLitterAmount', 'cs'] , header=None)
        if(i == 1):
            df_sum = df
        else:
            df_sum += df
    
    #平均値計算
    ave_df = df_sum / file_count
    mean_df = ave_df['cs'].mean()
    print(mean_df)

    #プロット
    plt.plot(ave_df['time'], ave_df['cs'], color="gray", label="Multiple")    
    
#ラベルの追加
plt.xlabel('Time(steps)')
plt.ylabel('Energy Consumption C(s)')

#表示範囲の指定
plt.xlim(0,5000000)
#plt.xlim(500000, 1500000)
#plt.xlim(1500000, 2500000)
#plt.ylim(15000, 35000)
plt.ylim(0, 70000)

#plt.xticks([0, 1000000, 2000000, 3000000])

#凡例の追加
plt.legend()

#指数表記から普通の表記に変換
plt.ticklabel_format(style='plain',axis='x')
plt.ticklabel_format(style='plain',axis='y')

#フォルダがない場合は、作成
p_dir = pathlib.Path("../../../../Volumes/ExternalDisk1/Patrolling/result/cs_graph_ave_compare")
if not p_dir.exists():
    p_dir.mkdir(parents=True)
    
#日付
date = datetime.datetime.now().strftime('%Y-%m-%d %H-%M-%S')

#グラフの保存
plt.savefig(str(p_dir) + '/' + 'cs_graph_3600_ave_compare' + date +'.png'
           , bbox_inches="tight")

#plt.savefig(str(p_dir) + '/' + 'cs_graph_3600_ave_compare_PlannedStop_' + str(file_count) + '_' + date + '.png'
#           , bbox_inches="tight")

#グラフの表示
plt.show()

print("Showing C(s) Average Comparing graph is completed.")
# Out:
# 53975.00275862066
# TimeChange :
# 23893.96115025166
# 23110.859827462264
# Showing C(s) Average Comparing graph is completed.
